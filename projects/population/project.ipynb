# %%
import pandas

# %%
df1 = pandas.read_json("data/population_estimates.json")
df1
# Out:
#        Country Code   Population                     Region  Year
# 0               900  2536274.721                      WORLD  1950
# 1               900  2583816.786                      WORLD  1951
# 2               900  2630584.384                      WORLD  1952
# 3               900  2677230.358                      WORLD  1953
# 4               900  2724302.468                      WORLD  1954
# 5               900  2772242.535                      WORLD  1955
# 6               900  2821383.444                      WORLD  1956
# 7               900  2871952.278                      WORLD  1957
# 8               900  2924081.243                      WORLD  1958
# 9               900  2977824.686                      WORLD  1959
# 10              900  3033212.527                      WORLD  1960
# 11              900  3090305.279                      WORLD  1961
# 12              900  3149244.245                      WORLD  1962
# ...

# %%
df1_t = df1.T
df1_t
# Out:
# Region              WORLD        WORLD        WORLD        WORLD        WORLD  \
# Country Code      900.000      900.000      900.000      900.000      900.000
# Population    2536274.721  2583816.786  2630584.384  2677230.358  2724302.468
#
# Region              WORLD        WORLD        WORLD        WORLD        WORLD  \
# Country Code      900.000      900.000      900.000      900.000      900.000
# Population    2772242.535  2821383.444  2871952.278  2924081.243  2977824.686
#
# Region        ...  Wallis and Futuna Islands  Wallis and Futuna Islands  \
# Country Code  ...                    876.000                    876.000
# Population    ...                     14.434                     14.229
#
# Region        Wallis and Futuna Islands  Wallis and Futuna Islands  \
# Country Code                    876.000                    876.000
# Population                       13.984                     13.706
#
# ...
